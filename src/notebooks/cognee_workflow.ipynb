# %%
import cognee

   # Create a clean slate for cognee -- reset data and system state
await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)
    

await cognee.add("./data/Allplan_2020_Manual.pdf")
    
    # Process with LLMs to build the knowledge graph
await cognee.cognify()
    
    # Search the knowledge graph
results = await cognee.search(
    query_text="How can I control the height of a pattern element in the layout to be a specific size, independent of the drawing scale, in Allplan 2020?"
)
    
# Print
for result in results:
    print(result)
# Out:
# 2025-11-22T15:27:13.396836 [info     ] Database deleted successfully. [cognee.shared.logging_utils]
#
# Deleting cache...
#
# ✓ Cache deleted successfully!
#
# 2025-11-22T15:27:13.598143 [info     ] Pipeline run started: `894b8174-1afa-5ccd-9cc8-9208f9632633` [run_tasks_with_telemetry()]
# User 8f28fd58-999b-49e6-a1f8-f7399e6a28ec has registered.
# 2025-11-22T15:27:13.833410 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2025-11-22T15:27:14.058671 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2025-11-22T15:27:14.310027 [info     ] Coroutine task completed: `ingest_data` [run_tasks_base]
#
# 2025-11-22T15:27:14.521986 [info     ] Coroutine task completed: `resolve_data_directories` [run_tasks_base]
#
# 2025-11-22T15:27:14.763423 [info     ] Pipeline run completed: `894b8174-1afa-5ccd-9cc8-9208f9632633` [run_tasks_with_telemetry()]
#
# ...
